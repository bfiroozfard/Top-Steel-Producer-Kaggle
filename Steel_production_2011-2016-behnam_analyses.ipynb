# %%
import pandas as pd
import numpy as np

# %%
# List contents in the current working directory
# !ls
# Out:
# data
# datasets_1995_3417_Top 100 Global Steel Producers (2011-2016).csv
# README.md
# Steel_production_2011-2016-behnam_analyses.ipynb

# %%
# Navigate into the `data` sub-directory
# %cd data/
# Out:
# D:\learnpython2\Top-Steel-Producer-Kaggle\data

# %%
# Print new working directory
! pwd
# Out:
# /d/learnpython2/Top-Steel-Producer-Kaggle/data

# %%
db = pd.read_csv("D:/learnpython2/Top-Steel-Producer-Kaggle/data/b1.csv")
db1 = pd.read_csv("b1.csv")

# Are they the same?
print(pd.DataFrame.equals(db,db1))
# Out:
# True

# %%
db.columns
# Out:
# Index(['Companies', 'Headquarters', '2011 Tonnage (Millions)',
#        '2012 Tonnage (Millions)', '2013 Tonnage (Millions)',
#        '2014 Tonnage (Millions)', '2015 Tonnage (Millions)',
#        '2016 Tonnage (Millions)', '2015 Ranking', '2016 Ranking'],
#       dtype='object')

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
# Companies                  100 non-null object
# Headquarters               100 non-null object
# 2011 Tonnage (Millions)    100 non-null float64
# 2012 Tonnage (Millions)    100 non-null float64
# 2013 Tonnage (Millions)    100 non-null float64
# 2014 Tonnage (Millions)    100 non-null float64
# 2015 Tonnage (Millions)    100 non-null float64
# 2016 Tonnage (Millions)    100 non-null float64
# 2015 Ranking               91 non-null float64
# 2016 Ranking               98 non-null float64
# dtypes: float64(8), object(2)
# memory usage: 7.9+ KB

# %%
db.shape
# Out:
# (100, 10)

# %%
db.size
# Out:
# 1000

# %%
db.dtypes
# Out:
# Companies                   object
# Headquarters                object
# 2011 Tonnage (Millions)    float64
# 2012 Tonnage (Millions)    float64
# 2013 Tonnage (Millions)    float64
# 2014 Tonnage (Millions)    float64
# 2015 Tonnage (Millions)    float64
# 2016 Tonnage (Millions)    float64
# 2015 Ranking               float64
# 2016 Ranking               float64
# dtype: object

# %%
db.head(10)
# Out:
#                                            Companies Headquarters  \
# 0                                     ArcelorMittal    Luxembourg
# 1  China Baowu Group (merger of Baosteel Group an...        China
# 2                                         HBIS Group        China
# 3        Nippon Steel and Sumitomo Metal Corporation        Japan
# 4                                              POSCO  South Korea
# 5                                     Baosteel Group        China
# 6                                      Shagang Group        China
# 7                                      Ansteel Group        China
# 8                              JFE Steel Corporation        Japan
# 9                                     Shougang Group        China
#
#    2011 Tonnage (Millions)  2012 Tonnage (Millions)  2013 Tonnage (Millions)  \
# 0                    97.25                    93.58                    96.10
# 1                    81.02                    79.12                    83.22
# 2                    44.36                    42.84                    45.79
# 3                    33.39                    47.86                    50.13
# 4                    39.12                    39.88                    38.42
# 5                    43.34                    42.70                    43.91
# 6                    31.92                    32.31                    35.08
# 7                    29.75                    30.23                    33.69
# 8                    29.90                    30.41                    31.16
# 9                    30.04                    31.42                    31.52
#
#    2014 Tonnage (Millions)  2015 Tonnage (Millions)  2016 Tonnage (Millions)  \
# 0                    98.09                    97.14                    95.45
# 1                    76.40                    60.71                    63.81
# 2                    47.09                    47.75                    46.18
# 3                    49.30                    46.37                    46.16
# 4                    41.59                    41.97                    41.56
# 5                    43.35                    34.94                     0.00
# 6                    35.33                    34.21                    33.25
# 7                    34.35                    32.50                    33.19
# 8                    31.41                    29.83                    30.29
# 9                    30.78                    28.55                    26.80
#
#    2015 Ranking  2016 Ranking
# 0           1.0           1.0
# 1           NaN           2.0
# 2           2.0           3.0
# 3           3.0           4.0
# 4           4.0           5.0
# 5           5.0           NaN
# 6           6.0           6.0
# 7           7.0           7.0
# 8           8.0           8.0
# 9           9.0           9.0

# %%
db.isnull()
# Out:
#     Companies  Headquarters  2011 Tonnage (Millions)  2012 Tonnage (Millions)  \
# 0       False         False                    False                    False
# 1       False         False                    False                    False
# 2       False         False                    False                    False
# 3       False         False                    False                    False
# 4       False         False                    False                    False
# ..        ...           ...                      ...                      ...
# 95      False         False                    False                    False
# 96      False         False                    False                    False
# 97      False         False                    False                    False
# 98      False         False                    False                    False
# 99      False         False                    False                    False
#
#     2013 Tonnage (Millions)  2014 Tonnage (Millions)  2015 Tonnage (Millions)  \
# 0                     False                    False                    False
# 1                     False                    False                    False
# 2                     False                    False                    False
# 3                     False                    False                    False
# 4                     False                    False                    False
# ..                      ...                      ...                      ...
# 95                    False                    False                    False
# 96                    False                    False                    False
# 97                    False                    False                    False
# 98                    False                    False                    False
# 99                    False                    False                    False
#
#     2016 Tonnage (Millions)  2015 Ranking  2016 Ranking
# 0                     False         False         False
# 1                     False          True         False
# 2                     False         False         False
# 3                     False         False         False
# 4                     False         False         False
# ..                      ...           ...           ...
# 95                    False          True         False
# 96                    False         False         False
# 97                    False         False         False
# 98                    False          True         False
# 99                    False          True         False
#
# [100 rows x 10 columns]

# %%
db.isna()
# Out:
#     Companies  Headquarters  2011 Tonnage (Millions)  2012 Tonnage (Millions)  \
# 0       False         False                    False                    False
# 1       False         False                    False                    False
# 2       False         False                    False                    False
# 3       False         False                    False                    False
# 4       False         False                    False                    False
# ..        ...           ...                      ...                      ...
# 95      False         False                    False                    False
# 96      False         False                    False                    False
# 97      False         False                    False                    False
# 98      False         False                    False                    False
# 99      False         False                    False                    False
#
#     2013 Tonnage (Millions)  2014 Tonnage (Millions)  2015 Tonnage (Millions)  \
# 0                     False                    False                    False
# 1                     False                    False                    False
# 2                     False                    False                    False
# 3                     False                    False                    False
# 4                     False                    False                    False
# ..                      ...                      ...                      ...
# 95                    False                    False                    False
# 96                    False                    False                    False
# 97                    False                    False                    False
# 98                    False                    False                    False
# 99                    False                    False                    False
#
#     2016 Tonnage (Millions)  2015 Ranking  2016 Ranking
# 0                     False         False         False
# 1                     False          True         False
# 2                     False         False         False
# 3                     False         False         False
# 4                     False         False         False
# ..                      ...           ...           ...
# 95                    False          True         False
# 96                    False         False         False
# 97                    False         False         False
# 98                    False          True         False
# 99                    False          True         False
#
# [100 rows x 10 columns]

# %%
db.isnull().any()
# Out:
# Companies                  False
# Headquarters               False
# 2011 Tonnage (Millions)    False
# 2012 Tonnage (Millions)    False
# 2013 Tonnage (Millions)    False
# 2014 Tonnage (Millions)    False
# 2015 Tonnage (Millions)    False
# 2016 Tonnage (Millions)    False
# 2015 Ranking                True
# 2016 Ranking                True
# dtype: bool

# %%
db.isnull().any().any()
# Out:
# True

# %%
db.isnull().sum()
# Out:
# Companies                  0
# Headquarters               0
# 2011 Tonnage (Millions)    0
# 2012 Tonnage (Millions)    0
# 2013 Tonnage (Millions)    0
# 2014 Tonnage (Millions)    0
# 2015 Tonnage (Millions)    0
# 2016 Tonnage (Millions)    0
# 2015 Ranking               9
# 2016 Ranking               2
# dtype: int64

# %%
db.isnull().sum().sum()
# Out:
# 11

# %%
nan_rows = db[db['2015 Ranking'].isnull()]
nan_rows
# Out:
#                                             Companies Headquarters  \
# 1   China Baowu Group (merger of Baosteel Group an...        China
# 58                                      Tianjin Steel        China
# 59                            Tsingshan Holding Group        China
# 69                                       Ji'nan Steel        China
# 72                           Tianjin Metallurgy Group        China
# 89                                      Tianzhu Steel        China
# 95                                      Outokumpu Oyj       Sweden
# 98                                      Tranvic Steel        China
# 99                                    Tosyali Holding       Turkey
#
#     2011 Tonnage (Millions)  2012 Tonnage (Millions)  2013 Tonnage (Millions)  \
# 1                     81.02                    79.12                    83.22
# 58                     0.00                     0.00                     0.00
# 59                     0.00                     0.00                     0.00
# 69                     0.00                     0.00                     0.00
# 72                     0.00                     0.00                     0.00
# 89                     0.00                     0.00                     0.00
# 95                     1.68                     1.68                     2.97
# 98                     0.00                     0.00                     0.00
# 99                     0.00                     0.00                     0.00
#
#     2014 Tonnage (Millions)  2015 Tonnage (Millions)  2016 Tonnage (Millions)  \
# 1                     76.40                    60.71                    63.81
# 58                     0.00                     5.94                     5.82
# 59                     0.00                     0.00                     5.80
# 69                     0.00                     4.49                     5.01
# 72                     0.00                     5.69                     4.88
# 89                     0.00                     3.09                     3.49
# 95                     3.41                     2.71                     3.20
# 98                     2.63                     2.66                     3.02
# 99                     0.00                     0.00                     3.00
#
#     2015 Ranking  2016 Ranking
# 1            NaN           2.0
# 58           NaN          57.0
# 59           NaN          58.0
# 69           NaN          68.0
# 72           NaN          71.0
# 89           NaN          88.0
# 95           NaN          94.0
# 98           NaN          97.0
# 99           NaN          98.0

# %%
db['2015 Ranking'].isnull()
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
#       ...
# 95     True
# 96    False
# 97    False
# 98     True
# 99     True
# Name: 2015 Ranking, Length: 100, dtype: bool

# %%
db.describe()
# Out:
#        2011 Tonnage (Millions)  2012 Tonnage (Millions)  \
# count               100.000000               100.000000
# mean                 11.040300                11.328000
# std                  15.222306                15.049308
# min                   0.000000                 0.000000
# 25%                   2.762500                 3.242500
# 50%                   6.365000                 7.020000
# 75%                  13.627500                13.847500
# max                  97.250000                93.580000
#
#        2013 Tonnage (Millions)  2014 Tonnage (Millions)  \
# count               100.000000                100.00000
# mean                 12.113800                 12.46410
# std                  15.469211                 15.09306
# min                   0.000000                  0.00000
# 25%                   3.430000                  3.90750
# 50%                   7.625000                  7.94000
# 75%                  14.292500                 14.63000
# max                  96.100000                 98.09000
#
#        2015 Tonnage (Millions)  2016 Tonnage (Millions)  2015 Ranking  \
# count               100.000000                100.00000     91.000000
# mean                 12.104200                 11.64640     46.758242
# std                  13.828638                 13.53232     26.796493
# min                   0.000000                  0.00000      1.000000
# 25%                   4.475000                  4.47250     24.500000
# 50%                   7.600000                  7.10000     47.000000
# 75%                  14.342500                 13.90000     68.500000
# max                  97.140000                 95.45000     94.000000
#
#        2016 Ranking
# count     98.000000
# mean      49.500000
# std       28.434134
# min        1.000000
# 25%       25.250000
# 50%       49.500000
# 75%       73.750000
# max       98.000000

# %%
db['2011 Tonnage (Millions)'].sum()
# Out:
# 1104.03

# %%
db.sort_values(['2011 Tonnage (Millions)'],ascending=False)
# Out:
#                                             Companies Headquarters  \
# 0                                      ArcelorMittal    Luxembourg
# 1   China Baowu Group (merger of Baosteel Group an...        China
# 2                                          HBIS Group        China
# 5                                      Baosteel Group        China
# 4                                               POSCO  South Korea
# ..                                                ...          ...
# 66                                        Yuhua Steel        China
# 65                                         RIVA Group   Luxembourg
# 56                               Binxin Special Steel        China
# 62                                           ILVA SpA        Italy
# 99                                    Tosyali Holding       Turkey
#
#     2011 Tonnage (Millions)  2012 Tonnage (Millions)  2013 Tonnage (Millions)  \
# 0                     97.25                    93.58                    96.10
# 1                     81.02                    79.12                    83.22
# 2                     44.36                    42.84                    45.79
# 5                     43.34                    42.70                    43.91
# 4                     39.12                    39.88                    38.42
# ..                      ...                      ...                      ...
# 66                     0.00                     0.00                     0.00
# 65                     0.00                     0.00                     7.59
# 56                     0.00                     0.00                     3.14
# 62                     0.00                     0.00                     5.68
# 99                     0.00                     0.00                     0.00
#
#     2014 Tonnage (Millions)  2015 Tonnage (Millions)  2016 Tonnage (Millions)  \
# 0                     98.09                    97.14                    95.45
# 1                     76.40                    60.71                    63.81
# 2                     47.09                    47.75                    46.18
# 5                     43.35                    34.94                     0.00
# 4                     41.59                    41.97                    41.56
# ..                      ...                      ...                      ...
# 66                     4.60                     4.60                     5.42
# 65                     7.76                     6.21                     5.47
# 56                     3.12                     4.48                     6.06
# 62                     6.22                     4.76                     5.67
# 99                     0.00                     0.00                     3.00
#
#     2015 Ranking  2016 Ranking
# 0            1.0           1.0
# 1            NaN           2.0
# 2            2.0           3.0
# 5            5.0           NaN
# 4            4.0           5.0
# ..           ...           ...
# 66          68.0          65.0
# 65          58.0          64.0
# 56          71.0          55.0
# 62          66.0          61.0
# 99           NaN          98.0
#
# [100 rows x 10 columns]

# %%
db.Headquarters.value_counts()
# Out:
# China            54
# India             6
# Russia            6
# Japan             4
# South Korea       3
# USA               3
# Brazil            3
# Sweden            2
# Germany           2
# Luxembourg        2
# Ukraine           2
# Turkey            2
# Taiwan, China     1
# Mexico            1
# Egypt             1
# KSA               1
# Iran              1
# Spain             1
# Australia         1
# UAE               1
# Italy             1
# Argentina         1
# Austria           1
# Name: Headquarters, dtype: int64

# %%
db.Headquarters.unique()
# Out:
# array(['Luxembourg', 'China', 'Japan', 'South Korea', 'India', 'USA',
#        'Germany', 'Russia', 'Brazil', 'Taiwan, China', 'Iran', 'Ukraine',
#        'Turkey', 'Sweden', 'Argentina', 'Austria', 'Spain', 'Italy',
#        'Australia', 'KSA', 'Mexico', 'Egypt', 'UAE'], dtype=object)

# %%
country_production=db.groupby(db.Headquarters)["2011 Tonnage (Millions)"].sum()
country_production
# Out:
# Headquarters
# Argentina          9.53
# Australia          6.00
# Austria            7.67
# Brazil            32.21
# China            556.78
# Egypt              4.32
# Germany           23.60
# India             56.96
# Iran              12.58
# Italy              0.00
# Japan             74.44
# KSA                5.28
# Luxembourg        97.25
# Mexico             3.81
# Russia            62.19
# South Korea       58.48
# Spain              7.84
# Sweden             7.35
# Taiwan, China     14.01
# Turkey             7.47
# UAE                0.00
# USA               41.88
# Ukraine           14.38
# Name: 2011 Tonnage (Millions), dtype: float64

# %%
db
# Out:
#                                             Companies Headquarters  \
# 0                                      ArcelorMittal    Luxembourg
# 1   China Baowu Group (merger of Baosteel Group an...        China
# 2                                          HBIS Group        China
# 3         Nippon Steel and Sumitomo Metal Corporation        Japan
# 4                                               POSCO  South Korea
# ..                                                ...          ...
# 95                                      Outokumpu Oyj       Sweden
# 96                                     Emirates Steel          UAE
# 97                                       Ganglu Steel        China
# 98                                      Tranvic Steel        China
# 99                                    Tosyali Holding       Turkey
#
#     2011 Tonnage (Millions)  2012 Tonnage (Millions)  2013 Tonnage (Millions)  \
# 0                     97.25                    93.58                    96.10
# 1                     81.02                    79.12                    83.22
# 2                     44.36                    42.84                    45.79
# 3                     33.39                    47.86                    50.13
# 4                     39.12                    39.88                    38.42
# ..                      ...                      ...                      ...
# 95                     1.68                     1.68                     2.97
# 96                     0.00                     2.38                     2.88
# 97                     3.01                     3.06                     3.10
# 98                     0.00                     0.00                     0.00
# 99                     0.00                     0.00                     0.00
#
#     2014 Tonnage (Millions)  2015 Tonnage (Millions)  2016 Tonnage (Millions)  \
# 0                     98.09                    97.14                    95.45
# 1                     76.40                    60.71                    63.81
# 2                     47.09                    47.75                    46.18
# 3                     49.30                    46.37                    46.16
# 4                     41.59                    41.97                    41.56
# ..                      ...                      ...                      ...
# 95                     3.41                     2.71                     3.20
# 96                     2.39                     3.01                     3.15
# 97                     3.07                     3.07                     3.07
# 98                     2.63                     2.66                     3.02
# 99                     0.00                     0.00                     3.00
#
#     2015 Ranking  2016 Ranking
# 0            1.0           1.0
# 1            NaN           2.0
# 2            2.0           3.0
# 3            3.0           4.0
# 4            4.0           5.0
# ..           ...           ...
# 95           NaN          94.0
# 96          94.0          95.0
# 97          93.0          96.0
# 98           NaN          97.0
# 99           NaN          98.0
#
# [100 rows x 10 columns]

# %%
a=db.groupby(db.Headquarters).agg(sum)
b=pd.DataFrame(a)

# %%
c=b.iloc[:,[0,1,2,3,4,5]].copy()
c
# Out:
#                2011 Tonnage (Millions)  2012 Tonnage (Millions)  \
# Headquarters
# Argentina                         9.53                     8.71
# Australia                         6.00                     4.23
# Austria                           7.67                     7.36
# Brazil                           32.21                    31.61
# China                           556.78                   559.42
# Egypt                             4.32                     4.56
# Germany                          23.60                    20.55
# India                            56.96                    57.49
# Iran                             12.58                    13.61
# Italy                             0.00                     0.00
# Japan                            74.44                    89.17
# KSA                               5.28                     5.20
# Luxembourg                       97.25                    93.58
# Mexico                            3.81                     3.88
# Russia                           62.19                    71.19
# South Korea                      58.48                    60.31
# Spain                             7.84                     7.62
# Sweden                            7.35                     6.93
# Taiwan, China                    14.01                    12.73
# Turkey                            7.47                     7.87
# UAE                               0.00                     2.38
# USA                              41.88                    41.57
# Ukraine                          14.38                    22.83
#
#                2013 Tonnage (Millions)  2014 Tonnage (Millions)  \
# Headquarters
# Argentina                         9.00                     9.38
# Australia                         4.20                     4.10
# Austria                           8.02                     7.95
# Brazil                           30.31                    30.46
# China                           614.28                   631.80
# Egypt                             4.33                     4.01
# Germany                          21.44                    22.97
# India                            62.66                    64.21
# Iran                             14.29                    14.42
# Italy                             5.68                     6.22
# Japan                            92.52                    92.35
# KSA                               5.47                     6.29
# Luxembourg                      103.69                   105.85
# Mexico                            4.16                     4.42
# Russia                           68.54                    67.68
# South Korea                      59.05                    65.21
# Spain                             6.99                     7.03
# Sweden                            8.54                    11.48
# Taiwan, China                    14.29                    15.40
# Turkey                            8.27                     8.49
# UAE                               2.88                     2.39
# USA                              40.54                    47.09
# Ukraine                          22.23                    17.21
#
#                2015 Tonnage (Millions)  2016 Tonnage (Millions)
# Headquarters
# Argentina                         8.40                     7.98
# Australia                         4.52                     5.63
# Austria                           7.76                     7.47
# Brazil                           27.20                    24.07
# China                           622.80                   572.09
# Egypt                             3.28                     3.66
# Germany                          23.99                    24.04
# India                            65.45                    68.53
# Iran                             14.10                    14.02
# Italy                             4.76                     5.67
# Japan                            87.54                    87.36
# KSA                               5.23                     5.27
# Luxembourg                      103.35                   100.92
# Mexico                            4.46                     4.65
# Russia                           62.91                    63.19
# South Korea                      65.77                    64.94
# Spain                             7.08                     6.94
# Sweden                           10.30                    11.19
# Taiwan, China                    14.82                    15.52
# Turkey                            8.93                    12.18
# UAE                               3.01                     3.15
# USA                              40.31                    41.22
# Ukraine                          14.45                    14.95

# %%
 c['ave_production']=c.mean(axis=1)

# %%
c['sum production']=c.iloc[:,[1,2,3,4,5,6]].sum(axis=1)

# %%
c.sort_values(['ave_production'],ascending=False,inplace=True)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
c.head()
# Out:
#               2011 Tonnage (Millions)  2012 Tonnage (Millions)  \
# Headquarters
# China                          556.78                   559.42
# Luxembourg                      97.25                    93.58
# Japan                           74.44                    89.17
# Russia                          62.19                    71.19
# India                           56.96                    57.49
#
#               2013 Tonnage (Millions)  2014 Tonnage (Millions)  \
# Headquarters
# China                          614.28                   631.80
# Luxembourg                     103.69                   105.85
# Japan                           92.52                    92.35
# Russia                          68.54                    67.68
# India                           62.66                    64.21
#
#               2015 Tonnage (Millions)  2016 Tonnage (Millions)  \
# Headquarters
# China                          622.80                   572.09
# Luxembourg                     103.35                   100.92
# Japan                           87.54                    87.36
# Russia                          62.91                    63.19
# India                           65.45                    68.53
#
#               ave_production  sum production
# Headquarters
# China             592.861667     3593.251667
# Luxembourg        100.773333      608.163333
# Japan              87.230000      536.170000
# Russia             65.950000      399.460000
# India              62.550000      380.890000

# %%
c.index
`
# Out:
# Index(['Argentina', 'Australia', 'Austria', 'Brazil', 'China', 'Egypt',
#        'Germany', 'India', 'Iran', 'Italy', 'Japan', 'KSA', 'Luxembourg',
#        'Mexico', 'Russia', 'South Korea', 'Spain', 'Sweden', 'Taiwan, China',
#        'Turkey', 'UAE', 'USA', 'Ukraine'],
#       dtype='object', name='Headquarters')

# %%
plt.figure(figsize=(15, 3))
plt.plot(c.index, c.ave_production,'bx--', label='line chart ',)  # Plot some data on the (implicit) axes.
plt.xlabel('Head Quarters')
plt.ylabel('Average Steel Production /million Tonnage ')
plt.title("Top 100 Steel producer")
plt.xticks(rotation=30, fontsize='small')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15, 6))

plt.subplot(211)
plt.bar(c.index, c.ave_production)
plt.xticks(rotation=30, fontsize='small')

plt.subplot(212)
plt.scatter(c.index, c.ave_production)
plt.xticks(rotation=30, fontsize='small')

plt.show()

# %%
d=c.iloc[:,0:5].copy()
d.plot.bar(stacked=True, alpha=0.5)

# %%
e=c.iloc[:,6].copy()
e.head()
# Out:
# Headquarters
# China         592.861667
# Luxembourg    100.773333
# Japan          87.230000
# Russia         65.950000
# India          62.550000
# Name: ave_production, dtype: float64

# %%
from sklearn import preprocessing

x = e.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df = pd.DataFrame(x_scaled)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-404033325238> in <module>
#       3 x = e.values #returns a numpy array
#       4 min_max_scaler = preprocessing.MinMaxScaler()
# ----> 5 x_scaled = min_max_scaler.fit_transform(x)
#       6 df = pd.DataFrame(x_scaled)
#
# ~\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     569         if y is None:
#     570             # fit method of arity 1 (unsupervised transformation)
# --> 571             return self.fit(X, **fit_params).transform(X)
#     572         else:
#     573             # fit method of arity 2 (supervised transformation)
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y)
#     337         # Reset internal state before fitting
#     338         self._reset()
# --> 339         return self.partial_fit(X, y)
#     340
#     341     def partial_fit(self, X, y=None):
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in partial_fit(self, X, y)
#     371         X = check_array(X,
#     372                         estimator=self, dtype=FLOAT_DTYPES,
# --> 373                         force_all_finite="allow-nan")
#     374
#     375         data_min = np.nanmin(X, axis=0)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     554                     "Reshape your data either using array.reshape(-1, 1) if "
#     555                     "your data has a single feature or array.reshape(1, -1) "
# --> 556                     "if it contains a single sample.".format(array))
#     557
#     558         # in the future np.flexible dtypes will be handled like object dtypes
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[592.86166667 100.77333333  87.23        65.95        62.55
#   62.29333333  42.10166667  29.31        22.765       17.675
#   14.46166667  13.83666667   9.29833333   8.86833333   8.83333333
#    7.705        7.25         5.45666667   4.78         4.23
#    4.02666667   3.72166667   2.30166667].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
normalized_df=(e-e.min())/(e.max()-e.min())

# %%
normalized_df
# Out:
# Headquarters
# China            1.000000
# Luxembourg       0.166743
# Japan            0.143810
# Russia           0.107776
# India            0.102019
# South Korea      0.101584
# USA              0.067394
# Brazil           0.045733
# Germany          0.034651
# Ukraine          0.026032
# Taiwan, China    0.020591
# Iran             0.019532
# Sweden           0.011848
# Turkey           0.011119
# Argentina        0.011060
# Austria          0.009150
# Spain            0.008379
# KSA              0.005342
# Australia        0.004197
# Mexico           0.003265
# Egypt            0.002921
# Italy            0.002404
# UAE              0.000000
# Name: ave_production, dtype: float64

# %%
normalized_df.plot.bar()

# %%
e.plot.pie(figsize=(10, 10))

# %%
import seaborn as sns

# %%
d.head()
# Out:
#               2011 Tonnage (Millions)  2012 Tonnage (Millions)  \
# Headquarters
# China                          556.78                   559.42
# Luxembourg                      97.25                    93.58
# Japan                           74.44                    89.17
# Russia                          62.19                    71.19
# India                           56.96                    57.49
#
#               2013 Tonnage (Millions)  2014 Tonnage (Millions)  \
# Headquarters
# China                          614.28                   631.80
# Luxembourg                     103.69                   105.85
# Japan                           92.52                    92.35
# Russia                          68.54                    67.68
# India                           62.66                    64.21
#
#               2015 Tonnage (Millions)
# Headquarters
# China                          622.80
# Luxembourg                     103.35
# Japan                           87.54
# Russia                          62.91
# India                           65.45

# %%
sns.barplot(x=d.index, hue=["2011","2012","2013","2014","2015"],y=d)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-87-d88912cd7aef> in <module>
# ----> 1 sns.barplot(x=d.index, hue=["2011","2012","2013","2014","2015"],y=d)
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3147                           estimator, ci, n_boot, units,
#    3148                           orient, color, palette, saturation,
# -> 3149                           errcolor, errwidth, capsize, dodge)
#    3150
#    3151     if ax is None:
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1605         """Initialize the plotter."""
#    1606         self.establish_variables(x, y, hue, data, orient,
# -> 1607                                  order, hue_order, units)
#    1608         self.establish_colors(color, palette, saturation)
#    1609         self.estimate_statistic(estimator, ci, n_boot)
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     205                 # Group the numeric data
#     206                 plot_data, value_label = self._group_longform(vals, groups,
# --> 207                                                               group_names)
#     208
#     209                 # Now handle the hue levels for nested ordering
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in _group_longform(self, vals, grouper, order)
#     244         # Ensure that the groupby will work
#     245         if not isinstance(vals, pd.Series):
# --> 246             vals = pd.Series(vals)
#     247
#     248         # Group the val data
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     314                 data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     315
# --> 316                 data = SingleBlockManager(data, index, fastpath=True)
#     317
#     318         generic.NDFrame.__init__(self, data, fastpath=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in __init__(self, block, axis, do_integrity_check, fastpath)
#    1514
#    1515         if not isinstance(block, Block):
# -> 1516             block = make_block(block, placement=slice(0, len(axis)), ndim=1)
#    1517
#    1518         self.blocks = tuple([block])
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in make_block(values, placement, klass, ndim, dtype, fastpath)
#    3282         values = DatetimeArray._simple_new(values, dtype=dtype)
#    3283
# -> 3284     return klass(values, ndim=ndim, placement=placement)
#    3285
#    3286
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in __init__(self, values, placement, ndim)
#    2790             values = np.array(values, dtype=object)
#    2791
# -> 2792         super().__init__(values, ndim=ndim, placement=placement)
#    2793
#    2794     @property
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in __init__(self, values, placement, ndim)
#     126             raise ValueError(
#     127                 "Wrong number of items passed {val}, placement implies "
# --> 128                 "{mgr}".format(val=len(self.values), mgr=len(self.mgr_locs))
#     129             )
#     130
#
# ValueError: Wrong number of items passed 5, placement implies 23
